# %% [markdown]
# <h2 align="center" > Credit Card Premiums Prediction </h2>

# %% [markdown]
# ### Import Important Libraries

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split

# %% [markdown]
# <h2 align="center" > Load Datasets </h2>

# %%
df = pd.read_excel("premiums.xlsx")
# df.shape

# %%
df.columns = df.columns.str.replace(" ","_").str.lower()

# %%
### print some few rows of the data sets 
print("some few rows of datasets")
df.head(4)
# Out:
# some few rows of datasets
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
# 2   49  Female  Northeast        Married                     2       Normal
# 3   30  Female  Southeast        Married                     3       Normal
#
#   smoking_status employment_status income_level  income_lakhs  \
# 0     No Smoking          Salaried         <10L             6
# 1        Regular          Salaried         <10L             6
# 2     No Smoking     Self-Employed    10L - 25L            20
# 3     No Smoking          Salaried        > 40L            77
#
#        medical_history insurance_plan  annual_premium_amount
# 0             Diabetes         Bronze                   9053
# 1             Diabetes         Bronze                  16339
# 2  High blood pressure         Silver                  18164
# 3           No Disease           Gold                  20303

# %% [markdown]
# <h2 align="center" > Data Cleaning & EDA </h2>

# %% [markdown]
# ### Handle Missing Values

# %%
df.isnull().sum()
# Out:
# age                       0
# gender                    0
# region                    0
# marital_status            0
# number_of_dependants      0
# bmi_category              0
# smoking_status           11
# employment_status         2
# income_level             13
# income_lakhs              0
# medical_history           0
# insurance_plan            0
# annual_premium_amount     0
# dtype: int64

# %%
df.dropna(inplace=True)
df.head(5)
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
# 2   49  Female  Northeast        Married                     2       Normal
# 3   30  Female  Southeast        Married                     3       Normal
# 4   18    Male  Northeast      Unmarried                     0   Overweight
#
#   smoking_status employment_status income_level  income_lakhs  \
# 0     No Smoking          Salaried         <10L             6
# 1        Regular          Salaried         <10L             6
# 2     No Smoking     Self-Employed    10L - 25L            20
# 3     No Smoking          Salaried        > 40L            77
# 4        Regular     Self-Employed        > 40L            99
#
#        medical_history insurance_plan  annual_premium_amount
# 0             Diabetes         Bronze                   9053
# 1             Diabetes         Bronze                  16339
# 2  High blood pressure         Silver                  18164
# 3           No Disease           Gold                  20303
# 4  High blood pressure         Silver                  13365

# %%
df.isnull().sum()
# Out:
# age                      0
# gender                   0
# region                   0
# marital_status           0
# number_of_dependants     0
# bmi_category             0
# smoking_status           0
# employment_status        0
# income_level             0
# income_lakhs             0
# medical_history          0
# insurance_plan           0
# annual_premium_amount    0
# dtype: int64

# %% [markdown]
# ### Handling Duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Baisc anlysis

# %%
df.describe()
# Out:
#                 age  number_of_dependants  income_lakhs  annual_premium_amount
# count  49976.000000          49976.000000  49976.000000           49976.000000
# mean      34.591764              1.711842     23.021150           15766.810189
# std       15.000378              1.498195     24.221794            8419.995271
# min       18.000000             -3.000000      1.000000            3501.000000
# 25%       22.000000              0.000000      7.000000            8607.750000
# 50%       31.000000              2.000000     17.000000           13928.000000
# 75%       45.000000              3.000000     31.000000           22273.500000
# max      356.000000              5.000000    930.000000           43471.000000

# %% [markdown]
# ### Data cleaning Number Of Dependants

# %%
df[df['number_of_dependants']<0]['number_of_dependants'].unique()
# Out:
# array([-3, -1])

# %%
df['number_of_dependants'] = df['number_of_dependants'].abs()

# %%
df.describe()
# Out:
#                 age  number_of_dependants  income_lakhs  annual_premium_amount
# count  49976.000000          49976.000000  49976.000000           49976.000000
# mean      34.591764              1.717284     23.021150           15766.810189
# std       15.000378              1.491953     24.221794            8419.995271
# min       18.000000              0.000000      1.000000            3501.000000
# 25%       22.000000              0.000000      7.000000            8607.750000
# 50%       31.000000              2.000000     17.000000           13928.000000
# 75%       45.000000              3.000000     31.000000           22273.500000
# max      356.000000              5.000000    930.000000           43471.000000

# %% [markdown]
# ## 1. Numeric Columns

# %% [markdown]
# ### Univariate Analysis: Numeric Columns

# %% [markdown]
# ### Box Plot for Numeric columns

# %%
Numeric_columns = df.select_dtypes(["float" , "int"]).columns
Numeric_columns
# Out:
# Index(['age', 'number_of_dependants', 'income_lakhs', 'annual_premium_amount'], dtype='object')

# %%
for col in Numeric_columns : 
    sns.boxplot(x=df[col] , whis=1.0)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Box plots for numeric columns

# %% [markdown]
# ### Outlier Treatment: Age Column

# %%
df[df["age"]>100]
# Out:
#        age  gender     region marital_status  number_of_dependants  \
# 114    224    Male  Northeast        Married                     3
# 786    124  Female  Southwest      Unmarried                     0
# 1298   124  Female  Northwest      Unmarried                     0
# 1456   124  Female  Southwest      Unmarried                     1
# 1470   136    Male  Southeast        Married                     3
# 1773   203  Female  Southeast      Unmarried                     0
# 3658   136    Male  Southwest        Married                     2
# 4246   203    Male  Southeast      Unmarried                     0
# 5699   124  Female  Southeast      Unmarried                     1
# 5951   136    Male  Southwest        Married                     3
# 6233   136    Male  Southeast        Married                     3
# 8316   203    Male  Northwest        Married                     1
# 8816   124    Male  Northeast      Unmarried                     2
# 10900  203    Male  Southeast      Unmarried                     0
# 11765  136    Male  Southeast      Unmarried                     0
# 13311  356    Male  Southeast        Married                     4
# 14051  203  Female  Southeast      Unmarried                     0
# 14268  124    Male  Northwest      Unmarried                     1
# 15203  356  Female  Southeast      Unmarried                     0
# 15353  203  Female  Southwest      Unmarried                     1
# 15480  224  Female  Northwest      Unmarried                     0
# 15561  356    Male  Southeast        Married                     3
# 16062  224  Female  Northeast        Married                     3
# 18122  203    Male  Southeast        Married                     1
# 20192  136    Male  Southwest      Unmarried                     0
# 22265  356    Male  Southwest      Unmarried                     0
# 22294  124  Female  Southeast      Unmarried                     2
# 23538  203  Female  Southwest        Married                     3
# 24281  203  Female  Southwest        Married                     5
# 24294  124    Male  Northeast      Unmarried                     0
# 25119  203    Male  Northwest      Unmarried                     1
# 28773  356    Male  Southwest      Unmarried                     2
# 29267  203  Female  Southwest        Married                     3
# 29834  356    Male  Southeast      Unmarried                     0
# 30679  356  Female  Northwest      Unmarried                     1
# 30962  136  Female  Southeast        Married                     3
# 32612  203    Male  Southwest      Unmarried                     2
# 32893  136    Male  Northwest      Unmarried                     0
# 33278  136  Female  Southeast        Married                     2
# 33719  136    Male  Northeast      Unmarried                     1
# 34840  224  Female  Southwest        Married                     3
# 36301  356  Female  Northwest        Married                     2
# 36524  224  Female  Northeast      Unmarried                     0
# 36631  356  Female  Southeast      Unmarried                     1
# 37995  136    Male  Southeast        Married                     5
# 38023  136    Male  Southwest        Married                     3
# 39387  224    Male  Southeast      Unmarried                     1
# 39483  203    Male  Southeast        Married                     3
# 40188  124    Male  Northwest      Unmarried                     1
# 40211  136    Male  Southeast        Married                     2
# 40549  136  Female  Southeast      Unmarried                     1
# 43618  224    Male  Southeast      Unmarried                     0
# 44423  224  Female  Northwest      Unmarried                     0
# 45733  124    Male  Southeast      Unmarried                     1
# 46010  124  Female  Northwest      Unmarried                     2
# 47192  136  Female  Northeast      Unmarried                     1
# 47396  224    Male  Northeast      Unmarried                     0
# 49843  224    Male  Northwest      Unmarried                     0
#
#       bmi_category smoking_status employment_status income_level  \
# 114         Normal        Regular          Salaried    25L - 40L
# 786         Normal     No Smoking        Freelancer        > 40L
# 1298        Normal     No Smoking          Salaried         <10L
# 1456    Overweight     No Smoking          Salaried         <10L
# 1470    Overweight        Regular     Self-Employed    10L - 25L
# 1773        Normal     No Smoking        Freelancer         <10L
# 3658        Normal        Regular          Salaried    10L - 25L
# 4246        Normal     No Smoking        Freelancer    10L - 25L
# 5699        Normal     No Smoking     Self-Employed    25L - 40L
# 5951   Underweight        Regular     Self-Employed         <10L
# 6233   Underweight        Regular          Salaried    10L - 25L
# 8316    Overweight        Regular          Salaried         <10L
# 8816   Underweight        Regular        Freelancer    25L - 40L
# 10900      Obesity        Regular        Freelancer    10L - 25L
# 11765       Normal     No Smoking     Self-Employed    25L - 40L
# 13311   Overweight        Regular     Self-Employed         <10L
# 14051       Normal        Regular     Self-Employed        > 40L
# 14268  Underweight        Regular          Salaried        > 40L
# 15203      Obesity     No Smoking          Salaried    10L - 25L
# 15353       Normal     No Smoking        Freelancer         <10L
# 15480       Normal     No Smoking          Salaried         <10L
# 15561       Normal     Occasional          Salaried    10L - 25L
# 16062      Obesity     No Smoking     Self-Employed         <10L
# 18122       Normal     No Smoking     Self-Employed         <10L
# 20192       Normal     No Smoking          Salaried    10L - 25L
# 22265       Normal     No Smoking          Salaried    10L - 25L
# 22294      Obesity     Occasional        Freelancer    25L - 40L
# 23538   Overweight     No Smoking          Salaried    10L - 25L
# 24281       Normal     Occasional        Freelancer    10L - 25L
# 24294       Normal     No Smoking        Freelancer    10L - 25L
# 25119       Normal        Regular          Salaried    10L - 25L
# 28773   Overweight        Regular          Salaried    25L - 40L
# 29267       Normal     Occasional     Self-Employed    25L - 40L
# 29834       Normal     No Smoking     Self-Employed        > 40L
# 30679  Underweight     No Smoking        Freelancer         <10L
# 30962      Obesity        Regular          Salaried         <10L
# 32612  Underweight     No Smoking        Freelancer         <10L
# 32893   Overweight        Regular     Self-Employed    10L - 25L
# 33278      Obesity     Occasional     Self-Employed    10L - 25L
# 33719  Underweight        Regular        Freelancer    25L - 40L
# 34840      Obesity     Occasional        Freelancer         <10L
# 36301      Obesity     No Smoking     Self-Employed    10L - 25L
# 36524       Normal     Occasional        Freelancer    10L - 25L
# 36631       Normal     Occasional     Self-Employed    25L - 40L
# 37995      Obesity        Regular          Salaried    10L - 25L
# 38023       Normal     No Smoking          Salaried    25L - 40L
# 39387       Normal     No Smoking        Freelancer         <10L
# 39483  Underweight        Regular          Salaried         <10L
# 40188      Obesity     No Smoking     Self-Employed         <10L
# 40211   Overweight     No Smoking        Freelancer         <10L
# 40549   Overweight     No Smoking        Freelancer         <10L
# 43618       Normal     No Smoking        Freelancer         <10L
# 44423       Normal     No Smoking        Freelancer    10L - 25L
# 45733       Normal     No Smoking          Salaried        > 40L
# 46010   Overweight     No Smoking          Salaried         <10L
# 47192       Normal     No Smoking          Salaried         <10L
# 47396   Overweight     No Smoking     Self-Employed        > 40L
# 49843      Obesity     No Smoking          Salaried    10L - 25L
#
#        income_lakhs                      medical_history insurance_plan  \
# 114              26                           No Disease           Gold
# 786              46                           No Disease         Silver
# 1298              3                           No Disease         Bronze
# 1456              2                             Diabetes         Bronze
# 1470             15                  High blood pressure           Gold
# 1773              6                             Diabetes         Bronze
# 3658             20                   Diabetes & Thyroid           Gold
# 4246             18                           No Disease         Bronze
# 5699             29                           No Disease         Silver
# 5951              2                        Heart disease         Silver
# 6233             18                              Thyroid         Silver
# 8316              9                  High blood pressure         Silver
# 8816             37                           No Disease         Bronze
# 10900            24                           No Disease         Bronze
# 11765            34                           No Disease         Silver
# 13311             5  High blood pressure & Heart disease         Silver
# 14051            45                           No Disease         Silver
# 14268            50                           No Disease           Gold
# 15203            13                   Diabetes & Thyroid         Silver
# 15353             5                           No Disease         Bronze
# 15480             1                              Thyroid         Bronze
# 15561            15                  High blood pressure           Gold
# 16062             5                             Diabetes         Silver
# 18122             9                        Heart disease         Silver
# 20192            16                           No Disease         Bronze
# 22265            11                           No Disease         Bronze
# 22294            32                           No Disease           Gold
# 23538            20                              Thyroid           Gold
# 24281            11                              Thyroid         Silver
# 24294            14                           No Disease         Bronze
# 25119            10                             Diabetes         Silver
# 28773            25                             Diabetes           Gold
# 29267            38                             Diabetes           Gold
# 29834            97                  High blood pressure           Gold
# 30679             5                           No Disease         Bronze
# 30962             9                              Thyroid         Bronze
# 32612             4                           No Disease         Silver
# 32893            23                  High blood pressure         Bronze
# 33278            23                             Diabetes         Silver
# 33719            29                           No Disease         Bronze
# 34840             6                           No Disease         Silver
# 36301            10                             Diabetes           Gold
# 36524            22                              Thyroid         Silver
# 36631            37                           No Disease         Bronze
# 37995            17                  High blood pressure           Gold
# 38023            34                           No Disease         Silver
# 39387             8                           No Disease         Bronze
# 39483             7  High blood pressure & Heart disease         Silver
# 40188             6                           No Disease         Bronze
# 40211             5                  High blood pressure         Bronze
# 40549             6                           No Disease         Silver
# 43618             5                             Diabetes         Bronze
# 44423            14                           No Disease         Bronze
# 45733            61                           No Disease           Gold
# 46010             8                           No Disease         Bronze
# 47192             3                   Diabetes & Thyroid         Bronze
# 47396            61  High blood pressure & Heart disease           Gold
# 49843            22                              Thyroid         Silver
#
#        annual_premium_amount
# 114                    27523
# 786                    11752
# 1298                    5311
# 1456                   10238
# 1470                   31913
# 1773                    8762
# 3658                   31402
# 4246                    5254
# 5699                   10265
# 5951                   26127
# 6233                   18782
# 8316                   27415
# 8816                    7811
# 10900                   6279
# 11765                  13296
# 13311                  27576
# 14051                  12443
# 14268                  13319
# 15203                  21586
# 15353                   8339
# 15480                   8784
# 15561                  27314
# 16062                  19924
# 18122                  26388
# 20192                   5098
# 22265                   3625
# 22294                  14582
# 23538                  23745
# 24281                  16404
# 24294                   8823
# 25119                  18956
# 28773                  32080
# 29267                  27450
# 29834                  26729
# 30679                   6478
# 30962                  16236
# 32612                   9092
# 32893                  10332
# 33278                  20508
# 33719                   5478
# 34840                  18759
# 36301                  30640
# 36524                  16753
# 36631                   7308
# 37995                  33208
# 38023                  13332
# 39387                   4568
# 39483                  25937
# 40188                   5708
# 40211                  11333
# 40549                  18056
# 43618                   4759
# 44423                   5504
# 45733                  11557
# 46010                   7415
# 47192                   5343
# 47396                  32277
# 49843                  19626

# %%
df[df["age"]>100]["age"].unique()
# Out:
# array([224, 124, 136, 203, 356])

# %%
df[df["age"]<100]["age"].unique()
# Out:
# array([26, 29, 49, 30, 18, 56, 33, 43, 59, 22, 21, 46, 68, 60, 27, 25, 36,
#        20, 28, 32, 19, 55, 35, 52, 40, 23, 50, 41, 67, 37, 24, 34, 54, 42,
#        45, 44, 57, 38, 31, 58, 48, 51, 47, 39, 53, 66, 64, 65, 62, 61, 70,
#        72, 69, 71, 63])

# %%
df1 = df[df.age<=100].copy()
df1.age.describe()
# Out:
# count    49918.000000
# mean        34.401839
# std         13.681600
# min         18.000000
# 25%         22.000000
# 50%         31.000000
# 75%         45.000000
# max         72.000000
# Name: age, dtype: float64

# %% [markdown]
# ### Outlier Treatment: Income Column

# %%
def get_low_upp(col) :
    Q1 , Q3 = col.quantile([0.25 , 0.75])
    IQR = Q3 - Q1 
    lower_bound = Q1 - 1.5*IQR
    Upper_bound = Q3 + 1.5*IQR
    return lower_bound , Upper_bound

lower , upper = get_low_upp(df1["income_lakhs"])
lower , upper
# Out:
# (-29.0, 67.0)

# %%
df1[df1.income_lakhs > upper].shape
# Out:
# (3559, 13)

# %%
quantile_threshold = df1.income_lakhs.quantile(0.999)
quantile_threshold
# Out:
# np.float64(100.0)

# %%
df1[df1.income_lakhs > quantile_threshold].shape
# Out:
# (10, 13)

# %%
df_2 = df1[df1.income_lakhs <= quantile_threshold].copy()
df_2.shape
# Out:
# (49908, 13)

# %%
df_2.describe()
# Out:
#                 age  number_of_dependants  income_lakhs  annual_premium_amount
# count  49908.000000          49908.000000  49908.000000           49908.000000
# mean      34.401579              1.717640     22.889897           15765.739641
# std       13.681604              1.492032     22.170699            8418.674061
# min       18.000000              0.000000      1.000000            3501.000000
# 25%       22.000000              0.000000      7.000000            8608.000000
# 50%       31.000000              2.000000     17.000000           13928.000000
# 75%       45.000000              3.000000     31.000000           22270.500000
# max       72.000000              5.000000    100.000000           43471.000000

# %% [markdown]
# ### Distributing income using histogram

# %%
sns.histplot(df_2.income_lakhs , kde=True)
plt.show()

# %% [markdown]
# ### Distributing all the numeric_columns

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))
for i , columns in enumerate(Numeric_columns) :
    ax = axs[i//2, i%2]
    sns.histplot(df_2[columns], kde=True, ax=ax)
    ax.set_title(columns)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### scatter plot compare two colums

# %%
sns.scatterplot(df_2 , x="age" , y="annual_premium_amount")
plt.show()

# %%
numeric_features = ['age', 'income_lakhs', 'number_of_dependants']

fig, axes = plt.subplots(1, len(numeric_features), figsize=(18, 6))  # Adjust figure size as necessary

for ax, column in zip(axes, numeric_features):
    sns.scatterplot(x=df_2[column], y=df_2['annual_premium_amount'], ax=ax)
    ax.set_title(f'{column} vs. Annual Premium Amount')
    ax.set_xlabel(column)
    ax.set_ylabel('Annual Premium Amount')

plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# ## 2. Categorical Columns

# %%
categorical_columns = df_2.select_dtypes(include=["object"]).columns
categorical_columns
# Out:
# Index(['gender', 'region', 'marital_status', 'bmi_category', 'smoking_status',
#        'employment_status', 'income_level', 'medical_history',
#        'insurance_plan'],
#       dtype='object')

# %%
for col in categorical_columns : 
    print(col , ":" , df_2[col].unique())
# Out:
# gender : ['Male' 'Female']
# region : ['Northwest' 'Southeast' 'Northeast' 'Southwest']
# marital_status : ['Unmarried' 'Married']
# bmi_category : ['Normal' 'Obesity' 'Overweight' 'Underweight']
# smoking_status : ['No Smoking' 'Regular' 'Occasional' 'Smoking=0' 'Does Not Smoke'
#  'Not Smoking']
# employment_status : ['Salaried' 'Self-Employed' 'Freelancer']
# income_level : ['<10L' '10L - 25L' '> 40L' '25L - 40L']
# medical_history : ['Diabetes' 'High blood pressure' 'No Disease'
#  'Diabetes & High blood pressure' 'Thyroid' 'Heart disease'
#  'High blood pressure & Heart disease' 'Diabetes & Thyroid'
#  'Diabetes & Heart disease']
# insurance_plan : ['Bronze' 'Silver' 'Gold']

# %%
df_2['smoking_status'].replace({
    'Not Smoking': 'No Smoking',
    'Does Not Smoke': 'No Smoking',
    'Smoking=0': 'No Smoking'
}, inplace=True)

df_2['smoking_status'].unique()
# Out:
# array(['No Smoking', 'Regular', 'Occasional'], dtype=object)

# %% [markdown]
# ### Univariate Analysis

# %%
df_2["gender"].value_counts()
# Out:
# gender
# Male      27431
# Female    22477
# Name: count, dtype: int64

# %%
count = df_2["gender"].value_counts(normalize=True)*100
count
# Out:
# gender
# Male      54.963132
# Female    45.036868
# Name: proportion, dtype: float64

# %%
sns.barplot(x=count.index , y=count.values)
plt.show()

# %%
fig, axes = plt.subplots(3,3, figsize=(18, 12))  # Adjust figure size as necessary
axes = axes.flatten()
for ax, column in zip(axes, categorical_columns):
    category_count = df_2[column].value_counts(normalize=True)*100
    sns.barplot(x=category_count.index, y=category_count.values, ax=ax)
    ax.set_title(f'{column} vs. annual_premium_amount')
    ax.set_title(f'Percentage Distribution of {column}')
    ax.set_ylabel('Percentage of Policyholders (%)')

plt.tight_layout()  # Adjust layout
plt.show()

# %%
crosstab = pd.crosstab(df_2["income_level"] , df["insurance_plan"])
crosstab
# Out:
# insurance_plan  Bronze  Gold  Silver
# income_level
# 10L - 25L         5307  3880    5182
# 25L - 40L         3683  2840    3750
# <10L             12226   931    5486
# > 40L              329  3653    2641

# %%
print(crosstab)
crosstab.plot(kind="bar" , stacked=True)
plt.title('Income vs Plan')
plt.ylabel('Count')
plt.show()
# Out:
# insurance_plan  Bronze  Gold  Silver
# income_level
# 10L - 25L         5307  3880    5182
# 25L - 40L         3683  2840    3750
# <10L             12226   931    5486
# > 40L              329  3653    2641

# %%
sns.heatmap(crosstab , annot=True , fmt="d")
plt.title('Heatmap of Income vs Plan')
plt.show()

# %% [markdown]
# <h2 align="center"> Feature Engineering</h2>

# %%
df_2.head(2)

# %%
df_2["medical_history"].unique()
# Out:
# array(['Diabetes', 'High blood pressure', 'No Disease',
#        'Diabetes & High blood pressure', 'Thyroid', 'Heart disease',
#        'High blood pressure & Heart disease', 'Diabetes & Thyroid',
#        'Diabetes & Heart disease'], dtype=object)

# %%
risk_score = {
    "Diabetes" : 6 ,
    "High blood pressure" : 6 ,
    "Thyroid" : 5 , 
    'Heart disease' : 8 ,
    "none": 0 ,
    'No Disease' : 0 
} 
df_2[["disease_1" , "disease_2" ]] = df_2["medical_history"].str.split("&" , expand=True)
df_2.head(3)
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
# 2   49  Female  Northeast        Married                     2       Normal
#
#   smoking_status employment_status income_level  income_lakhs  \
# 0     No Smoking          Salaried         <10L             6
# 1        Regular          Salaried         <10L             6
# 2     No Smoking     Self-Employed    10L - 25L            20
#
#        medical_history insurance_plan  annual_premium_amount  \
# 0             Diabetes         Bronze                   9053
# 1             Diabetes         Bronze                  16339
# 2  High blood pressure         Silver                  18164
#
#              disease_1 disease_2
# 0             Diabetes      None
# 1             Diabetes      None
# 2  High blood pressure      None

# %%
df_2["disease_1"].fillna("none" , inplace=True)
df_2["disease_2"].fillna("none" , inplace=True)
df_2["total_risk_score"] = 0 

for disease in ["disease_1" , "disease_2"] : 
    df_2["total_risk_score"] += df_2[disease].map(risk_score)
    max_score = df_2["total_risk_score"].max()
    min_score = df_2["total_risk_score"].min()
    df_2["normalized_score"] = (df_2["total_risk_score"] - min_score ) / (max_score - min_score)

df_2.sample(5)
# Out:
#        age gender     region marital_status  number_of_dependants  \
# 16374   21   Male  Southwest      Unmarried                     0
# 7580    25   Male  Southeast      Unmarried                     1
# 5036    38   Male  Northwest        Married                     3
# 34972   37   Male  Northwest        Married                     3
# 17130   33   Male  Southeast        Married                     3
#
#       bmi_category smoking_status employment_status income_level  \
# 16374       Normal        Regular        Freelancer         <10L
# 7580    Overweight        Regular     Self-Employed    25L - 40L
# 5036    Overweight        Regular          Salaried         <10L
# 34972   Overweight     No Smoking        Freelancer    25L - 40L
# 17130       Normal     No Smoking        Freelancer         <10L
#
#        income_lakhs medical_history insurance_plan  annual_premium_amount  \
# 16374             9      No Disease         Silver                  11968
# 7580             36      No Disease         Bronze                   7705
# 5036              4         Thyroid         Silver                  20799
# 34972            40         Thyroid         Silver                  17819
# 17130             8        Diabetes         Silver                  15872
#
#         disease_1 disease_2  total_risk_score  normalized_score
# 16374  No Disease      none               0.0             0.000
# 7580   No Disease      none               0.0             0.000
# 5036      Thyroid      none               5.0             0.625
# 34972     Thyroid      none               5.0             0.625
# 17130    Diabetes      none               6.0             0.750

# %% [markdown]
# ### Encoded Text column

# %%
df_2['insurance_plan'] = df_2['insurance_plan'].map({'Bronze': 1, 'Silver': 2, 'Gold': 3})

# %%
df_2.income_level.unique()
# Out:
# array(['<10L', '10L - 25L', '> 40L', '25L - 40L'], dtype=object)

# %%
df_2["income_level"] = df_2["income_level"].map({'<10L':1, '10L - 25L': 2, '25L - 40L':3, '> 40L':4})
df_2.head()
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
# 2   49  Female  Northeast        Married                     2       Normal
# 3   30  Female  Southeast        Married                     3       Normal
# 4   18    Male  Northeast      Unmarried                     0   Overweight
#
#   smoking_status employment_status  income_level  income_lakhs  \
# 0     No Smoking          Salaried             1             6
# 1        Regular          Salaried             1             6
# 2     No Smoking     Self-Employed             2            20
# 3     No Smoking          Salaried             4            77
# 4        Regular     Self-Employed             4            99
#
#        medical_history  insurance_plan  annual_premium_amount  \
# 0             Diabetes               1                   9053
# 1             Diabetes               1                  16339
# 2  High blood pressure               2                  18164
# 3           No Disease               3                  20303
# 4  High blood pressure               2                  13365
#
#              disease_1 disease_2  total_risk_score  normalized_score
# 0             Diabetes      none               6.0              0.75
# 1             Diabetes      none               6.0              0.75
# 2  High blood pressure      none               6.0              0.75
# 3           No Disease      none               0.0              0.00
# 4  High blood pressure      none               6.0              0.75

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49908 entries, 0 to 49999
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              49908 non-null  int64
#  1   number_of_dependants             49908 non-null  int64
#  2   income_level                     49908 non-null  int64
#  3   income_lakhs                     49908 non-null  int64
#  4   medical_history                  49908 non-null  object
#  5   insurance_plan                   49908 non-null  int64
#  6   annual_premium_amount            49908 non-null  int64
#  7   disease_1                        49908 non-null  object
#  8   disease_2                        49908 non-null  object
#  9   total_risk_score                 45140 non-null  float64
#  10  normalized_score                 45140 non-null  float64
#  11  gender_Male                      49908 non-null  int64
#  12  region_Northwest                 49908 non-null  int64
#  13  region_Southeast                 49908 non-null  int64
#  14  region_Southwest                 49908 non-null  int64
#  15  marital_status_Unmarried         49908 non-null  int64
#  16  bmi_category_Obesity             49908 non-null  int64
#  17  bmi_category_Overweight          49908 non-null  int64
#  18  bmi_category_Underweight         49908 non-null  int64
#  19  smoking_status_Occasional        49908 non-null  int64
#  20  smoking_status_Regular           49908 non-null  int64
#  21  employment_status_Salaried       49908 non-null  int64
#  22  employment_status_Self-Employed  49908 non-null  int64
# dtypes: float64(2), int64(18), object(3)
# memory usage: 9.1+ MB
